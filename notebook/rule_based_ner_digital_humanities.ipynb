# %% [markdown]
# ## https://www.youtube.com/watch?v=ytAyCO-n8tY&t=38s

# %%
# !python -m spacy download en_core_web_sm
# !python -m spacy download en_core_web_lg
# !python -m spacy download en_core_web_md
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.6.2-py3-none-any.whl (1.5 MB)
# Collecting click
#   Using cached click-8.0.1-py3-none-any.whl (97 kB)
# Requirement already satisfied: tqdm in c:\users\teozz\miniconda3\envs\spacy_2\lib\site-packages (from nltk) (4.61.0)
# Collecting regex
#   Downloading regex-2021.4.4-cp37-cp37m-win_amd64.whl (269 kB)
# Requirement already satisfied: joblib in c:\users\teozz\appdata\roaming\python\python37\site-packages (from nltk) (1.0.1)
# Requirement already satisfied: colorama in c:\users\teozz\miniconda3\envs\spacy_2\lib\site-packages (from click->nltk) (0.4.4)
# Requirement already satisfied: importlib-metadata in c:\users\teozz\miniconda3\envs\spacy_2\lib\site-packages (from click->nltk) (4.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\teozz\miniconda3\envs\spacy_2\lib\site-packages (from importlib-metadata->click->nltk) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\teozz\miniconda3\envs\spacy_2\lib\site-packages (from importlib-metadata->click->nltk) (3.10.0.0)
# Installing collected packages: regex, click, nltk
# Successfully installed click-8.0.1 nltk-3.6.2 regex-2021.4.4

# %%
import spacy
import nltk
import pickle
from spacy.lang.en import English
from spacy.pipeline import EntityRuler
import json

# %%
nlp = spacy.load('en_core_web_lg')

# %%
def load_data(file):
    with open(file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    return data

def generate_better_characters(file):
    characters = load_data(file)
    new_characters = [character for character in characters]
    print("Original number of new_characters {}".format(len(new_characters)))
    
    for item in characters:
        item  = item.replace("The", "").replace("the", "").replace("and", "").replace("And", "")
        names = item.split(" ")
        for name in names:
            name = name.strip()
            new_characters.append(name)
        if "(" in item:
            names = item.split("(")
            for name in names:
                name = name.replace(")", "").strip()
                new_characters.append(name)
        if "," in item:
            names = item.split(",")
            for name in names:
                name = name.replace("and", "").strip()
                if " " in name:
                    new_names = name.split()
                    for x in new_names:
                        x = x.strip()
                        new_characters.append(x)
                new_characters.append(name)
    final_characters = []
    titles = ["Dr.", "Professor", "Mr.", "Mrs.", "Ms.", "Miss", "Aunt", "Uncle", "Mr. and Mrs."]
    
    for character in new_characters:
        if "" != character:
            final_characters.append(character)
            for title in titles:
                titled_char = f"{title} {character}"
                final_characters.append(titled_char)
            
    final_characters = list(set(final_characters))
    final_characters.sort()
    
    print("After stripping, total number of new characters {}".format(len(final_characters)))
    return final_characters


def create_training_data(file, label_type):
    data = generate_better_characters(file)
    patterns = []
    for item in data:
        pattern = {
            "label": label_type,
            "pattern": item
        }
        patterns.append(pattern)
    return patterns

def generate_rules(patterns):
    nlp = English()
    ruler = EntityRuler(nlp)
    ruler.add_patterns(patterns)
    nlp.add_pipe(ruler)
    nlp.to_disk('hr_ner')

def test_model(model, text):
    doc = nlp(text)
    results = []
    for ent in doc.ents:
        results.append(ent.text)
    return results

def save_data(file, data):
    with open(file, "w", encoding='utf-8') as file:
        json.dump(data, file, indent=4)

# %%
patterns = create_training_data("../data/digital_humanity/hp_characters.json", 'PERSON')
generate_rules(patterns)
# Out:
# Original number of new_characters 207
# After stripping, total number of new characters 5119

# %%
nlp = spacy.load("hr_ner")

# %%
with open("../data/digital_humanity/hp.txt") as f:
    text = f.read()
    chapters = text.split("CHAPTER")[1:]
    ie_data = {}
    for chapter in chapters:
        chapter_num, chapter_title =  chapter.split("\n\n")[0:2]
        chapter_num = chapter_num.strip()
        segments = chapter.split("\n\n")[2:]
        hits = []
        
        for segment in segments:
            segment = segment.strip()
            segment = segment.replace("\n", " ")
            results =  test_model(nlp,segment)
            for result in results:
                hits.append(result)
        ie_data[chapter_num] = hits

save_data("../data/digital_humanity/results/hp_data.json", ie_data)

# %%
# Out:
# {'ONE': ['Mr. and Mrs. Dursley',
#   'Mr. Dursley',
#   'Mrs. Dursley',
#   'Dudley',
#   'Mrs. Potter',
#   'Mrs. Dursley',
#   'Mrs. Dursley',
#   'Dudley',
#   'Mr. and Mrs. Dursley',
#   'Mr. Dursley',
#   'Mrs. Dursley',
#   'Dudley',
#   'Mr. Dursley',
#   'Mrs. Dursley',
#   'Dudley',
#   'Dudley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Harry',
#   'Mr. Dursley',
#   'Potter',
#   'Potter',
#   'Harry',
#   'Harry',
#   'Mrs. Dursley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Mr. Dursley',
#   'Mrs. Dursley',
#   'Mrs.',
#   'Dudley',
#   'Mr. Dursley',
#   'Dudley',
#   'Ted',
#   'Mr. Dursley',
#   'Mrs. Dursley',
#   'Petunia',
#   'Mrs. Dursley',
#   'Mr. Dursley',
#   'Mrs. Dursley',
#   'Mrs. Dursley',
#   'Mr. Dursley',
#   'Potter',
#   'Dudley',
#   'Mrs. Dursley',
#   'Harry',
#   'Mr. Dursley',
#   'Mrs. Dursley',
#   'Mr. Dursley',
#   'Mrs. Dursley',
#   'Mr. Dursley',
#   'Mrs. Dursley',
#   'Petunia',
#   'Petunia',
#   'Mr. Dursley',
#   'Albus Dumbledore',
#   'Albus Dumbledore',
#   'Mrs. Dursley',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Professor McGonagall',
#   'Professor McGonagall',
#   'Dedalus Diggle',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Dumbledore',
#   'Dumbledore',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Voldemort',
#   'Professor McGonagall',
#   'Dumbledore',
#   'Voldemort',
#   'Professor McGonagall',
#   'Voldemort',
#   'Dumbledore',
#   'Voldemort',
#   'Madam',
#   'Pomfrey',
#   'Professor McGonagall',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Dumbledore',
#   'Dumbledore',
#   'Dumbledore',
#   'Voldemort',
#   'Lily',
#   'James Potter',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Lily',
#   'James',
#   'Albus',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Potter',
#   'Harry',
#   'Harry Potter',
#   'Voldemort',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Harry',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Dumbledore',
#   'Dumbledore',
#   'Hagrid',
#   'Professor McGonagall',
#   'Harry',
#   'Professor McGonagall',
#   'Dumbledore',
#   'Harry Potter',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Dumbledore',
#   'Harry Potter',
#   'Harry',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Dumbledore',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Hagrid',
#   'Dumbledore',
#   'Professor Dumbledore',
#   'Sirius Black',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Professor McGonagall',
#   'Dumbledore',
#   'Dumbledore',
#   'Hagrid',
#   'Dumbledore',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Professor McGonagall',
#   'Hagrid',
#   'Lily',
#   'James',
#   'Harry',
#   'Hagrid',
#   'Professor McGonagall',
#   'Hagrid',
#   'Dumbledore',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Professor McGonagall',
#   'Dumbledore',
#   'Dumbledore',
#   'Hagrid',
#   'Sirius',
#   'Professor McGonagall',
#   'Professor Dumbledore',
#   'Hagrid',
#   'Professor McGonagall',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Dumbledore',
#   'Harry',
#   'Harry Potter',
#   'Mrs. Dursley',
#   'Dudley',
#   'Harry Potter'],
#  'TWO': ['Nearly',
#   'Mr. Dursley',
#   'Dudley Dursley',
#   'Harry Potter',
#   'Aunt Petunia',
#   'Harry',
#   'Harry',
#   'Nearly',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Aunt Petunia',
#   'Uncle Vernon',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Dudley',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Dudley',
#   'Marge',
#   'Dudley',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Aunt Petunia',
#   'Dudley',
#   'Aunt Petunia',
#   'Dudley',
#   'Uncle Vernon',
#   'Dudley',
#   'Dudley',
#   'Aunt Petunia',
#   'Harry',
#   'Uncle Vernon',
#   'Dudley',
#   'Aunt Petunia',
#   'Vernon',
#   'Mrs. Figg',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Mrs. Figg',
#   'Harry',
#   'Mrs. Figg',
#   'Aunt Petunia',
#   'Harry',
#   'Harry',
#   'Mrs. Figg',
#   'Marge',
#   'Uncle Vernon',
#   'Vernon',
#   'Harry',
#   'Aunt Petunia',
#   'Harry',
#   'Dudley',
#   'Aunt Petunia',
#   'Harry',
#   'Aunt Petunia',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Lord',
#   'Aunt Petunia',
#   'Dudley',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Dudley',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Aunt Petunia',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Aunt Petunia',
#   'Aunt Petunia',
#   'Dudley',
#   'Harry',
#   'Aunt Petunia',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Dudley',
#   'Mrs. Figg',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Uncle Vernon',
#   'Dudley',
#   'Uncle Vernon',
#   'Dudley',
#   'Uncle Vernon',
#   'Dudley',
#   'Harry',
#   'Aunt Petunia',
#   'Harry',
#   'Harry',
#   'Uncle Vernon',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Aunt Petunia',
#   'Dudley',
#   'Harry',
#   'Uncle Vernon',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Aunt Petunia',
#   'Harry',
#   'Harry',
#   'Aunt Petunia',
#   'Dudley',
#   'Harry',
#   'Aunt Petunia',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Harry Potter',
#   'Dudley'],
#  'THREE': ['Harry',
#   'Dudley',
#   'Mrs. Figg',
#   'Harry',
#   'Dudley',
#   'Dennis',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Uncle Vernon',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Aunt Petunia',
#   'Dudley',
#   'Harry',
#   'Mrs. Figg',
#   'Mrs. Figg',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Harry',
#   'Harry',
#   'Aunt Petunia',
#   'Harry',
#   'Aunt Petunia',
#   'Dudley',
#   'Harry',
#   'Dudley',
#   'Uncle Vernon',
#   'Harry',
#   'Uncle Vernon',
#   'Dudley',
#   'Dudley',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Uncle Vernon',
#   'Marge',
#   'Harry',
#   'Harry',
#   'Potter',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Marge',
#   'Aunt Petunia',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Uncle Vernon',
#   'Petunia',
#   'Dudley',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Vernon',
#   'Vernon',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Dudley',
#   'Uncle Vernon',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Vernon',
#   'Aunt Petunia',
#   'Uncle Vernon',
#   'Vernon',
#   'Harry',
#   'Uncle Vernon',
#   'Petunia',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Uncle Vernon',
#   'Marge',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Nearly',
#   'Dudley',
#   'Dudley',
#   'Dudley',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Uncle Vernon',
#   'Harry',
#   'Dudley',
#   'Potter',
#   'Uncle Vernon',
#   'Harry',
#   'Uncle Vernon',
#   'Dudley',
#   'Harry',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Vernon',
#   'Petunia',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Aunt Petunia',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Dudley',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Aunt Petunia',
#   'Dudley',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Dudley',
#   'Aunt Petunia',
#   'Uncle Vernon',
#   'Dudley',
#   'Uncle Vernon',
#   'Dudley',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Potter',
#   'Potter',
#   'Harry',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Uncle Vernon',
#   'Dudley',
#   'Aunt Petunia',
#   'Uncle Vernon',
#   'Great',
#   'Great',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Harry',
#   'Aunt Petunia',
#   'Dudley',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Harry'],
#  'FOUR': ['Dudley',
#   'Uncle Vernon',
#   'Dudley',
#   'Dudley',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Uncle Vernon',
#   'Dursley',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Rubeus Hagrid',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Uncle Vernon',
#   'Dudley',
#   'Dursley',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Uncle Vernon',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Uncle Vernon',
#   'Vernon Dursley',
#   'Hagrid',
#   'Hagrid',
#   'Dumbledore',
#   'Dumbledore',
#   'Dursley',
#   'Harry',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Potter',
#   'Mr. Potter',
#   'Minerva McGonagall',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Professor Dumbledore',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Uncle Vernon',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Uncle Vernon',
#   'Harry',
#   'Aunt Petunia',
#   'Lily',
#   'Lily',
#   'Potter',
#   'Harry',
#   'Hagrid',
#   'Lily',
#   'James Potter',
#   'Harry Potter',
#   'Harry',
#   'Hagrid',
#   'Dumbledore',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Voldemort',
#   'Hagrid',
#   'Harry',
#   'Dumbledore',
#   'Dumbledore',
#   'Hagrid',
#   'Harry',
#   'Bones',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Dumbledore',
#   'Uncle Vernon',
#   'Harry',
#   'Uncle Vernon',
#   'Hagrid',
#   'Hagrid',
#   'Uncle Vernon',
#   'Dursley',
#   'Uncle Vernon',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Aunt Petunia',
#   'Uncle Vernon',
#   'Dudley',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Harry Potter',
#   'Uncle Vernon',
#   'Hagrid',
#   'Lily',
#   'James Potter',
#   'Albus',
#   'Uncle Vernon',
#   'Hagrid',
#   'Dudley',
#   'Dudley',
#   'Harry',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Dudley',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Dumbledore',
#   'Great',
#   'Dumbledore',
#   'Hagrid',
#   'Harry'],
#  'FIVE': ['Harry',
#   'Hagrid',
#   'Aunt Petunia',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Uncle Vernon',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Dumbledore',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Uncle Vernon',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Uncle Vernon',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Dumbledore',
#   'Cornelius Fudge',
#   'Dumbledore',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Bathilda Bagshot',
#   'Newt Scamander',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Lord',
#   'Harry',
#   'Harry Potter',
#   'Harry',
#   'Mr. Potter',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Mr. Potter',
#   'Mr. Potter',
#   'Mr. Potter',
#   'Diggle',
#   'Dedalus Diggle',
#   'Harry',
#   'Dedalus Diggle',
#   'Dedalus Diggle',
#   'Harry',
#   'Professor Quirrell',
#   'Hagrid',
#   'Harry',
#   'Professor Quirrell',
#   'Potter',
#   'Professor Quirrell',
#   'Harry',
#   'Professor Quirrell',
#   'Professor Quirrell',
#   'Potter',
#   'Professor Quirrell',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Professor Quirrell',
#   'Black',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Brown',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Mr. Harry Potter',
#   'Sir',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Professor Dumbledore',
#   'Hagrid',
#   'Hagrid',
#   'Griphook',
#   'Griphook',
#   'Hagrid',
#   'Harry',
#   'Griphook',
#   'Harry',
#   'Hagrid',
#   'Dumbledore',
#   'Griphook',
#   'Harry',
#   'Griphook',
#   'Hagrid',
#   'Harry',
#   'Griphook',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Griphook',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Griphook',
#   'Griphook',
#   'Harry',
#   'Hagrid',
#   'Griphook',
#   'Griphook',
#   'Harry',
#   'Griphook',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Dudley',
#   'Hagrid',
#   'Madam Malkin',
#   'Harry',
#   'Harry',
#   'Madam Malkin',
#   'Madam Malkin',
#   'Harry',
#   'Madam Malkin',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Madam Malkin',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Madam Malkin',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Dudley',
#   'Hagrid',
#   'Harry',
#   'Dudley',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Professor Quirrell',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry Potter',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Rubeus',
#   'Rubeus Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Mr. Potter',
#   'Harry',
#   'Harry',
#   'Mr. Potter',
#   'Harry',
#   'Mr. Potter',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Mr. Potter',
#   'Harry',
#   'Mr. Potter',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Professor Quirrell',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Hagrid'],
#  'SIX': ['Harry',
#   'Dudley',
#   'Harry',
#   'Aunt Petunia',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hedwig',
#   'Hedwig',
#   'Aunt Petunia',
#   'Hedwig',
#   'Harry',
#   'Dudley',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Harry',
#   'Dudley',
#   'Uncle Vernon',
#   'Harry',
#   'Hedwig',
#   'Harry',
#   'Aunt Petunia',
#   'Dudley',
#   'Harry',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Uncle Vernon',
#   'Uncle Vernon',
#   'Harry',
#   'Harry',
#   'Hedwig',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Ginny',
#   'Percy',
#   'Harry',
#   'Fred',
#   'Fred',
#   'George',
#   'George',
#   'George',
#   'Fred',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Neville',
#   'Lee',
#   'Harry',
#   'Hedwig',
#   'Harry',
#   'Fred',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry Potter',
#   'Harry',
#   'Harry',
#   'Fred',
#   'George',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Percy',
#   'Harry',
#   'Percy',
#   'Percy',
#   'Percy',
#   'Percy',
#   'Great',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Harry Potter',
#   'Harry',
#   'Ginny',
#   'Fred',
#   'Fred',
#   'Ginny',
#   'George',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Lee Jordan',
#   'Ron',
#   'Harry',
#   'Fred',
#   'George Weasley',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry Potter',
#   'Ron',
#   'Harry',
#   'Fred',
#   'George',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Ron',
#   'Ron',
#   'Ron',
#   'Bill',
#   'Charlie',
#   'Bill',
#   'Charlie',
#   'Percy',
#   'Fred',
#   'George',
#   'Bill',
#   'Charlie',
#   'Percy',
#   'Ron',
#   'Scabbers',
#   'Percy',
#   'Scabbers',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Dudley',
#   'Ron',
#   'Hagrid',
#   'Voldemort',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Albus Dumbledore',
#   'Dumbledore',
#   'Harry',
#   'Dumbledore',
#   'Ron',
#   'Harry',
#   'Dumbledore',
#   'Grindelwald',
#   'Professor Dumbledore',
#   'Harry',
#   'Dumbledore',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Dumbledore',
#   'Ron',
#   'Harry',
#   'Dumbledore',
#   'Ron',
#   'Harry',
#   'George',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Scabbers',
#   'Ron',
#   'Ron',
#   'Neville',
#   'Ron',
#   'Ron',
#   'Scabbers',
#   'Hermione Granger',
#   'Harry',
#   'Ron',
#   'Ron Weasley',
#   'Ron',
#   'Harry Potter',
#   'Harry',
#   'Hermione',
#   'Great',
#   'Harry',
#   'Hermione',
#   'Dumbledore',
#   'Ravenclaw',
#   'Neville',
#   'Ron',
#   'George',
#   'Harry',
#   'Ron',
#   'Ravenclaw',
#   'Ron',
#   'Scabbers',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Charlie',
#   'Bill',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Voldemort',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Neville',
#   'Hermione Granger',
#   'Harry',
#   'Madam Malkin',
#   'Harry',
#   'Harry Potter',
#   'Harry',
#   'Crabbe',
#   'Goyle',
#   'Harry',
#   'Malfoy',
#   'Draco Malfoy',
#   'Ron',
#   'Draco Malfoy',
#   'Harry',
#   'Potter',
#   'Harry',
#   'Harry',
#   'Draco Malfoy',
#   'Potter',
#   'Hagrid',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Malfoy',
#   'Harry',
#   'Crabbe',
#   'Goyle',
#   'Ron',
#   'Goyle',
#   'Ron',
#   'Ron',
#   'Goyle',
#   'Goyle',
#   'Scabbers',
#   'Goyle',
#   'Crabbe',
#   'Malfoy',
#   'Goyle',
#   'Scabbers',
#   'Hermione Granger',
#   'Ron',
#   'Scabbers',
#   'Ron',
#   'Harry',
#   'Scabbers',
#   'Malfoy',
#   'Harry',
#   'Ron',
#   'Malfoy',
#   'Hermione',
#   'Scabbers',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Neville',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Ron',
#   'Neville',
#   'Hermione',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Trevor',
#   'Neville',
#   'Hagrid',
#   'Hagrid'],
#  'SEVEN': ['Harry',
#   'Professor McGonagall',
#   'Hagrid',
#   'Hagrid',
#   'Professor McGonagall',
#   'Harry',
#   'Professor McGonagall',
#   'Professor McGonagall',
#   'Great',
#   'Ravenclaw',
#   'Neville',
#   'Ron',
#   'Harry',
#   'Professor McGonagall',
#   'Harry',
#   'Ron',
#   'Fred',
#   'Harry',
#   'Hermione Granger',
#   'Harry',
#   'Professor McGonagall',
#   'Friar',
#   'Peeves',
#   'Fat',
#   'Friar',
#   'Friar',
#   'Professor McGonagall',
#   'Professor McGonagall',
#   'Harry',
#   'Ron',
#   'Great',
#   'Harry',
#   'Professor McGonagall',
#   'Harry',
#   'Hermione',
#   'Great',
#   'Harry',
#   'Professor McGonagall',
#   'Aunt Petunia',
#   'Harry',
#   'Ravenclaw',
#   'Ron',
#   'Harry',
#   'Fred',
#   'Harry',
#   'Harry',
#   'Professor McGonagall',
#   'Abbott',
#   'Hannah',
#   'Hannah',
#   'Harry',
#   'Fat',
#   'Friar',
#   'Bones',
#   'Susan',
#   'Susan',
#   'Hannah',
#   'Boot',
#   'Terry',
#   'Terry',
#   'Ravenclaw',
#   'Brown',
#   'Lavender',
#   'Harry',
#   'Ron',
#   'Bulstrode',
#   'Millicent',
#   'Harry',
#   'Dudley',
#   'Finch-Fletchley',
#   'Justin',
#   'Harry',
#   'Finnigan',
#   'Seamus',
#   'Harry',
#   'Granger',
#   'Hermione',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Professor McGonagall',
#   'Neville Longbottom',
#   'Neville',
#   'Neville',
#   'Malfoy',
#   'Malfoy',
#   'Crabbe',
#   'Goyle',
#   'Nott',
#   'Parkinson',
#   'Patil',
#   'Patil',
#   'Potter',
#   'Harry',
#   'Harry',
#   'Potter',
#   'Harry Potter',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Percy',
#   'Weasley',
#   'Potter',
#   'Potter',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Albus Dumbledore',
#   'Harry',
#   'Dumbledore',
#   'Harry',
#   'Thomas',
#   'Dean',
#   'Black',
#   'Ron',
#   'Harry',
#   'Ravenclaw',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Percy Weasley',
#   'Harry',
#   'Zabini',
#   'Blaise',
#   'Professor McGonagall',
#   'Harry',
#   'Albus Dumbledore',
#   'Harry',
#   'Percy',
#   'Percy',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Sir',
#   'Ron',
#   'Nearly Headless Nick',
#   'Sir',
#   'Seamus Finnigan',
#   'Nearly',
#   'Headless',
#   'Sir',
#   'Nearly Headless Nick',
#   'The Bloody Baron',
#   'Harry',
#   'Malfoy',
#   'Harry',
#   'Seamus',
#   'Nearly Headless Nick',
#   'Harry',
#   'Seamus',
#   'Neville',
#   'Ron',
#   'Neville',
#   'Great',
#   'Great',
#   'Great',
#   'Great',
#   'Harry',
#   'Percy Weasley',
#   'Hermione',
#   'Harry',
#   'Hagrid',
#   'Professor McGonagall',
#   'Professor Dumbledore',
#   'Professor Quirrell',
#   'Quirrell',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Percy',
#   'Harry',
#   'Harry',
#   'Professor Quirrell',
#   'Percy',
#   'Quirrell',
#   'Professor Snape',
#   'Quirrell',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Snape',
#   'Professor Dumbledore',
#   'Dumbledore',
#   'Weasley',
#   'Mr. Filch',
#   'Madam',
#   'Hooch',
#   'Harry',
#   'Percy',
#   'Percy',
#   'Dumbledore',
#   'Dumbledore',
#   'Harry',
#   'Dumbledore',
#   'Dumbledore',
#   'Weasley',
#   'Dumbledore',
#   'Percy',
#   'Great',
#   'Harry',
#   'Percy',
#   'Harry',
#   'Percy',
#   'Peeves',
#   'Percy',
#   'Peeves',
#   'Bloody',
#   'Baron',
#   'Peeves',
#   'Percy',
#   'Peeves',
#   'Neville',
#   'Peeves',
#   'Percy',
#   'The Bloody Baron',
#   'Percy',
#   'Neville',
#   'Percy',
#   'Great',
#   'Ron',
#   'Harry',
#   'Scabbers',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Professor Quirrell',
#   'Harry',
#   'Malfoy',
#   'Malfoy',
#   'Snape',
#   'Harry'],
#  'EIGHT': ['Harry',
#   'Harry',
#   'Harry',
#   'Nearly Headless Nick',
#   'Peeves',
#   'Peeves',
#   'Argus Filch',
#   'Harry',
#   'Ron',
#   'Filch',
#   'Professor Quirrell',
#   'Filch',
#   'Mrs.',
#   'Filch',
#   'Filch',
#   'Filch',
#   'Weasley',
#   'Mrs.',
#   'Harry',
#   'Professor Sprout',
#   'Professor Binns',
#   'Binns',
#   'Professor Flitwick',
#   'Harry',
#   'Professor McGonagall',
#   'Harry',
#   'Hermione Granger',
#   'Professor McGonagall',
#   'Hermione',
#   'Quirrell',
#   'Seamus Finnigan',
#   'Quirrell',
#   'Quirrell',
#   'Weasley',
#   'Quirrell',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Great',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Snape',
#   'McGonagall',
#   'Harry',
#   'Professor McGonagall',
#   'Harry',
#   'Great',
#   'Hedwig',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hedwig',
#   'Hagrid',
#   'Harry',
#   'Ron',
#   'Hedwig',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Professor Snape',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Flitwick',
#   'Flitwick',
#   'Harry',
#   'Harry Potter',
#   'Draco Malfoy',
#   'Crabbe',
#   'Goyle',
#   'Snape',
#   'Hagrid',
#   'Hagrid',
#   'Professor McGonagall',
#   'Snape',
#   'Professor McGonagall',
#   'Snape',
#   'Harry',
#   'Ron',
#   'Hermione Granger',
#   'Potter',
#   'Snape',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Snape',
#   'Hermione',
#   'Potter',
#   'Hermione',
#   'Harry',
#   'Malfoy',
#   'Crabbe',
#   'Goyle',
#   'Potter',
#   'Harry',
#   'Snape',
#   'Snape',
#   'Hermione',
#   'Potter',
#   'Hermione',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Seamus',
#   'Seamus',
#   'Snape',
#   'Hermione',
#   'Potter',
#   'Snape',
#   'Potter',
#   'Snape',
#   'Malfoy',
#   'Malfoy',
#   'Neville',
#   'Seamus',
#   'Neville',
#   'Snape',
#   'Neville',
#   'Snape',
#   'Seamus',
#   'Harry',
#   'Ron',
#   'Neville',
#   'Potter',
#   'Harry',
#   'Ron',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Ron',
#   'Snape',
#   'Fred',
#   'George',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Fang',
#   'Hagrid',
#   'Fang',
#   'Hagrid',
#   'Fang',
#   'Ron',
#   'Hagrid',
#   'Fang',
#   'Ron',
#   'Harry',
#   'Hagrid',
#   'Weasley',
#   'Hagrid',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Hagrid',
#   'Fang',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Hagrid',
#   'Mrs.',
#   'Fang',
#   'Harry',
#   'Hagrid',
#   'Snape',
#   'Hagrid',
#   'Ron',
#   'Harry',
#   'Snape',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Charlie',
#   'Hagrid',
#   'Ron',
#   'Harry',
#   'Hagrid',
#   'Ron',
#   'Hagrid',
#   'Charlie',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Snape',
#   'Harry'],
#  'NINE': ['Harry',
#   'Dudley',
#   'Draco Malfoy',
#   'Malfoy',
#   'Harry',
#   'Malfoy',
#   'Ron',
#   'Malfoy',
#   'Seamus Finnigan',
#   'Ron',
#   'Charlie',
#   'Ron',
#   'Dean Thomas',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Dean',
#   'Neville',
#   'Harry',
#   'Neville',
#   'Hermione Granger',
#   'Neville',
#   'Neville',
#   'Hermione',
#   'Harry',
#   'Hagrid',
#   'Malfoy',
#   'Malfoy',
#   'Neville',
#   'Neville',
#   'Draco Malfoy',
#   'Harry',
#   'Ron',
#   'Professor McGonagall',
#   'Malfoy',
#   'Malfoy',
#   'Crabbe',
#   'Goyle',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Fred',
#   'George Weasley',
#   'Madam',
#   'Hooch',
#   'Harry',
#   'Madam',
#   'Hooch',
#   'Harry',
#   'Hermione Granger',
#   'Neville',
#   'Harry',
#   'Neville',
#   'Madam',
#   'Hooch',
#   'Harry',
#   'Ron',
#   'Malfoy',
#   'Madam',
#   'Hooch',
#   'Neville',
#   'Madam',
#   'Hooch',
#   'Neville',
#   'Harry',
#   'Neville',
#   'Madam',
#   'Hooch',
#   'Neville',
#   'Harry',
#   'Neville',
#   'Madam',
#   'Hooch',
#   'Malfoy',
#   'Malfoy',
#   'Parvati Patil',
#   'Longbottom',
#   'Pansy Parkinson',
#   'Parvati',
#   'Malfoy',
#   'Longbottom',
#   'Malfoy',
#   'Harry',
#   'Malfoy',
#   'Longbottom',
#   'Harry',
#   'Malfoy',
#   'Potter',
#   'Harry',
#   'Hermione Granger',
#   'Madam',
#   'Hooch',
#   'Harry',
#   'Ron',
#   'Malfoy',
#   'Malfoy',
#   'Harry',
#   'Malfoy',
#   'Harry',
#   'Malfoy',
#   'Harry',
#   'Crabbe',
#   'Goyle',
#   'Malfoy',
#   'Harry',
#   'Malfoy',
#   'Harry',
#   'Professor McGonagall',
#   'Professor McGonagall',
#   'Miss Patil',
#   'Malfoy',
#   'Mr. Weasley',
#   'Potter',
#   'Harry',
#   'Malfoy',
#   'Crabbe',
#   'Goyle',
#   'Professor McGonagall',
#   'Professor McGonagall',
#   'Professor McGonagall',
#   'Harry',
#   'Dumbledore',
#   'Hagrid',
#   'Hagrid',
#   'Ron',
#   'Hagrid',
#   'Professor McGonagall',
#   'Professor Flitwick',
#   'Wood',
#   'Wood',
#   'Harry',
#   'Wood',
#   'Wood',
#   'Professor McGonagall',
#   'Wood',
#   'Harry',
#   'Professor McGonagall',
#   'Peeves',
#   'Peeves',
#   'Peeves',
#   'Professor McGonagall',
#   'Potter',
#   'Oliver Wood',
#   'Wood',
#   'Wood',
#   'Professor McGonagall',
#   'Potter',
#   'Harry',
#   'Professor McGonagall',
#   'Wood',
#   'Charlie Weasley',
#   'Wood',
#   'Potter',
#   'Wood',
#   'Professor McGonagall',
#   'Wood',
#   'Harry',
#   'Professor Dumbledore',
#   'Severus Snape',
#   'Professor McGonagall',
#   'Harry',
#   'Potter',
#   'Harry',
#   'Ron',
#   'Professor McGonagall',
#   'Ron',
#   'Harry',
#   'Wood',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Wood',
#   'Fred',
#   'George Weasley',
#   'Harry',
#   'George',
#   'Wood',
#   'Fred',
#   'Charlie',
#   'Harry',
#   'Wood',
#   'Lee Jordan',
#   'Gregory',
#   'Fred',
#   'George',
#   'Malfoy',
#   'Crabbe',
#   'Goyle',
#   'Potter',
#   'Harry',
#   'Crabbe',
#   'Goyle',
#   'Malfoy',
#   'Ron',
#   'Malfoy',
#   'Crabbe',
#   'Goyle',
#   'Crabbe',
#   'Malfoy',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Hermione Granger',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Malfoy',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Dean',
#   'Seamus',
#   'Neville',
#   'Ron',
#   'Filch',
#   'Mrs.',
#   'Harry',
#   'Malfoy',
#   'Ron',
#   'Harry',
#   'Hermione Granger',
#   'Ron',
#   'Hermione',
#   'Percy',
#   'Harry',
#   'Ron',
#   'Fat',
#   'Lady',
#   'Hermione',
#   'Ron',
#   'Professor McGonagall',
#   'Hermione',
#   'Fat',
#   'Lady',
#   'The Fat Lady',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Filch',
#   'Ron',
#   'Harry',
#   'Mrs.',
#   'Ron',
#   'Mrs.',
#   'Neville',
#   'Neville',
#   'Fat',
#   'Lady',
#   'Harry',
#   'Neville',
#   'Madam',
#   'Pomfrey',
#   'Neville',
#   'Neville',
#   'Bloody',
#   'Baron',
#   'Ron',
#   'Hermione',
#   'Neville',
#   'Quirrell',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Filch',
#   'Mrs.',
#   'Malfoy',
#   'Crabbe',
#   'Harry',
#   'Malfoy',
#   'Ron',
#   'Harry',
#   'Malfoy',
#   'Filch',
#   'Mrs.',
#   'Harry',
#   'Filch',
#   'Neville',
#   'Filch',
#   'Harry',
#   'Filch',
#   'Neville',
#   'Ron',
#   'Harry',
#   'Filch',
#   'Harry',
#   'Harry',
#   'Neville',
#   'Hermione',
#   'Ron',
#   'Malfoy',
#   'Hermione',
#   'Harry',
#   'Filch',
#   'Malfoy',
#   'Harry',
#   'Peeves',
#   'Peeves',
#   'Peeves',
#   'Peeves',
#   'Filch',
#   'Peeves',
#   'Ron',
#   'Peeves',
#   'Peeves',
#   'Peeves',
#   'Ron',
#   'Filch',
#   'Peeves',
#   'Hermione',
#   'Harry',
#   'Peeves',
#   'Filch',
#   'Peeves',
#   'Peeves',
#   'Peeves',
#   'Filch',
#   'Harry',
#   'Neville',
#   'Neville',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Filch',
#   'Filch',
#   'Harry',
#   'Filch',
#   'Fat',
#   'Lady',
#   'Harry',
#   'Neville',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Hagrid',
#   'Harry'],
#  'TEN': ['Malfoy',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Neville',
#   'Hermione',
#   'Neville',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Malfoy',
#   'Great',
#   'Harry',
#   'Harry',
#   'Oliver Wood',
#   'Professor McGonagall',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Crabbe',
#   'Goyle',
#   'Malfoy',
#   'Harry',
#   'Harry',
#   'Potter',
#   'Ron',
#   'Malfoy',
#   'Ron',
#   'Harry',
#   'Weasley',
#   'Malfoy',
#   'Ron',
#   'Professor Flitwick',
#   'Malfoy',
#   'Potter',
#   'Malfoy',
#   'Professor Flitwick',
#   'Harry',
#   'Professor McGonagall',
#   'Potter',
#   'Harry',
#   'Malfoy',
#   'Malfoy',
#   'Harry',
#   'Ron',
#   'Malfoy',
#   'Harry',
#   'Neville',
#   'Hermione',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Wood',
#   'Harry',
#   'Potter',
#   'Oliver Wood',
#   'Harry',
#   'Wood',
#   'McGonagall',
#   'Wood',
#   'Harry',
#   'Wood',
#   'Wood',
#   'Harry',
#   'Wood',
#   'Harry',
#   'Harry',
#   'Wood',
#   'Harry',
#   'Wood',
#   'Harry',
#   'Harry',
#   'Wood',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Wood',
#   'Wood',
#   'Weasley',
#   'Harry',
#   'Wood',
#   'Harry',
#   'Wood',
#   'Wood',
#   'Harry',
#   'Wood',
#   'Harry',
#   'Wood',
#   'Harry',
#   'Harry',
#   'Wood',
#   'Wood',
#   'Charlie Weasley',
#   'Harry',
#   'Professor Flitwick',
#   'Neville',
#   'Professor Flitwick',
#   'Harry',
#   'Seamus Finnigan',
#   'Neville',
#   'Ron',
#   'Hermione Granger',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Professor Flitwick',
#   'Harry',
#   'Seamus',
#   'Seamus',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Professor Flitwick',
#   'Miss Granger',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Great',
#   'Harry',
#   'Ron',
#   'Parvati Patil',
#   'Lavender',
#   'Hermione',
#   'Ron',
#   'Great',
#   'Hermione',
#   'Harry',
#   'Professor Quirrell',
#   'Professor Dumbledore',
#   'Professor Dumbledore',
#   'Percy',
#   'Harry',
#   'Ron',
#   'Peeves',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Percy',
#   'Ron',
#   'Harry',
#   'Percy',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Bloody',
#   'Baron',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Hermione Granger',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Professor McGonagall',
#   'Snape',
#   'Quirrell',
#   'Quirrell',
#   'Snape',
#   'Professor McGonagall',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Professor McGonagall',
#   'Harry',
#   'Ron',
#   'Snape',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Professor McGonagall',
#   'Miss Granger',
#   'Hermione',
#   'Ron',
#   'Hermione Granger',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Professor McGonagall',
#   'Miss Granger',
#   'Hermione',
#   'Harry',
#   'Hermione',
#   'Snape',
#   'Miss Granger',
#   'Professor McGonagall',
#   'Hermione',
#   'Professor McGonagall',
#   'Harry',
#   'Ron',
#   'Professor Dumbledore',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Fat',
#   'Lady',
#   'Hermione',
#   'Hermione Granger'],
#  'ELEVEN': ['Hagrid',
#   'Harry',
#   'Harry',
#   'Wood',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Wood',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Snape',
#   'Potter',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Snape',
#   'Ron',
#   'Hermione',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Snape',
#   'Snape',
#   'Filch',
#   'Snape',
#   'Filch',
#   'Snape',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Harry',
#   'Snape',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Hermione',
#   'Dumbledore',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Neville',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Great',
#   'Hermione',
#   'Harry',
#   'Harry',
#   'Seamus Finnigan',
#   'Seamus',
#   'Harry',
#   'Seamus',
#   'Ron',
#   'Hermione',
#   'Neville',
#   'Seamus',
#   'Dean',
#   'Harry',
#   'Scabbers',
#   'Potter',
#   'Dean',
#   'Hermione',
#   'Harry',
#   'Wood',
#   'Angelina Johnson',
#   'Wood',
#   'Fred Weasley',
#   'George',
#   'Oliver',
#   'Fred',
#   'Harry',
#   'Wood',
#   'Harry',
#   'Fred',
#   'George',
#   'Madam',
#   'Hooch',
#   'Harry',
#   'Marcus Flint',
#   'Harry',
#   'Flint',
#   'Potter',
#   'Harry',
#   'Madam',
#   'Hooch',
#   'Angelina Johnson',
#   'Weasley',
#   'Lee Jordan',
#   'Professor McGonagall',
#   'Alicia Spinnet',
#   'Oliver Wood',
#   'Johnson',
#   'Marcus Flint',
#   'Flint',
#   'Wood',
#   'Katie Bell',
#   'Flint',
#   'Fred',
#   'George Weasley',
#   'Johnson',
#   'Angelina',
#   'Hagrid',
#   'Ron',
#   'Hermione',
#   'Hagrid',
#   'Hagrid',
#   'Ron',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Wood',
#   'Wood',
#   'Angelina',
#   'Harry',
#   'Harry',
#   'Fred Weasley',
#   'Harry',
#   'Marcus Flint',
#   'Lee Jordan',
#   'Bell',
#   'Harry',
#   'Harry',
#   'Marcus Flint',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Madam',
#   'Hooch',
#   'Flint',
#   'Dean Thomas',
#   'Dean',
#   'Ron',
#   'Dean',
#   'Dean',
#   'Ron',
#   'Hagrid',
#   'Dean',
#   'Flint',
#   'Harry',
#   'Lee Jordan',
#   'Jordan',
#   'Professor McGonagall',
#   'Jordan',
#   'Flint',
#   'Harry',
#   'Harry',
#   'Wood',
#   'Lee',
#   'Flint',
#   'Spinnet',
#   'Bell',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Flint',
#   'Seamus',
#   'Hagrid',
#   'Hermione',
#   'Hagrid',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Snape',
#   'Ron',
#   'Snape',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Marcus',
#   'Flint',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Snape',
#   'Professor Quirrell',
#   'Snape',
#   'Snape',
#   'Snape',
#   'Snape',
#   'Harry',
#   'Neville',
#   'Ron',
#   'Neville',
#   'Hagrid',
#   'Harry',
#   'Flint',
#   'Harry',
#   'Lee Jordan',
#   'Harry',
#   'Hagrid',
#   'Ron',
#   'Hermione',
#   'Snape',
#   'Ron',
#   'Hermione',
#   'Hagrid',
#   'Snape',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Fluffy',
#   'Fluffy',
#   'Dumbledore',
#   'Harry',
#   'Hagrid',
#   'Snape',
#   'Hagrid',
#   'Snape',
#   'Harry',
#   'Hermione',
#   'Snape',
#   'Hagrid',
#   'Snape',
#   'Hagrid',
#   'Harry',
#   'Snape',
#   'Professor Dumbledore',
#   'Harry',
#   'Hagrid'],
#  'TWELVE': ['Weasley',
#   'Quirrell',
#   'Hagrid',
#   'Great',
#   'Professor Snape',
#   'Draco Malfoy',
#   'Harry',
#   'Crabbe',
#   'Goyle',
#   'Harry',
#   'Malfoy',
#   'Harry',
#   'Harry',
#   'Malfoy',
#   'Harry',
#   'Harry',
#   'Professor McGonagall',
#   'Harry',
#   'Ron',
#   'Mr. and Mrs. Weasley',
#   'Charlie',
#   'Hagrid',
#   'Hagrid',
#   'Ron',
#   'Ron',
#   'Weasley',
#   'Hagrid',
#   'Ron',
#   'Malfoy',
#   'Snape',
#   'Ron',
#   'Malfoy',
#   'Professor Snape',
#   'Hagrid',
#   'Malfoy',
#   'Hagrid',
#   'Snape',
#   'Weasley',
#   'Malfoy',
#   'Crabbe',
#   'Goyle',
#   'Ron',
#   'Malfoy',
#   'Harry',
#   'Malfoy',
#   'Snape',
#   'Hagrid',
#   'Great',
#   'Hagrid',
#   'Great',
#   'Professor McGonagall',
#   'Professor Flitwick',
#   'Hagrid',
#   'Hagrid',
#   'Hermione',
#   'Ron',
#   'Ron',
#   'Professor Flitwick',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hermione',
#   'Harry',
#   'Hagrid',
#   'Ron',
#   'Hagrid',
#   'Hagrid',
#   'Snape',
#   'Great',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Madam',
#   'Pince',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Madam',
#   'Pince',
#   'Snape',
#   'Harry',
#   'Madam',
#   'Pince',
#   'Ron',
#   'Hermione',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Malfoy',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Seamus Finnigan',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Uncle Vernon',
#   'Aunt Petunia',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Hagrid',
#   'Ron',
#   'Weasley',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Fred',
#   'George Weasley',
#   'Harry',
#   'Harry',
#   'Weasley',
#   'Fred',
#   'George',
#   'Harry',
#   'Fred',
#   'Harry',
#   'Ron',
#   'George',
#   'Ron',
#   'George',
#   'Percy Weasley',
#   'Fred',
#   'Percy',
#   'Harry',
#   'Percy',
#   'George',
#   'Percy',
#   'Harry',
#   'Harry',
#   'Fred',
#   'Dumbledore',
#   'Professor Flitwick',
#   'Percy',
#   'Harry',
#   'Hagrid',
#   'Professor McGonagall',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Mrs.',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Percy',
#   'Percy',
#   'Fred',
#   'George',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Filch',
#   'Ron',
#   'Harry',
#   'Fat',
#   'Lady',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Filch',
#   'Filch',
#   'Harry',
#   'Filch',
#   'Harry',
#   'Filch',
#   'Snape',
#   'Harry',
#   'Filch',
#   'Snape',
#   'Harry',
#   'Filch',
#   'Snape',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Snape',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Ron',
#   'Bill',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Mrs.',
#   'Ron',
#   'Harry',
#   'Filch',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Hagrid',
#   'Harry',
#   'Filch',
#   'Snape',
#   'Mrs.',
#   'Hermione',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Albus Dumbledore',
#   'Harry',
#   'Dumbledore',
#   'Harry',
#   'Dumbledore',
#   'Harry',
#   'Sir',
#   'Ron',
#   'Dumbledore',
#   'Harry',
#   'Harry',
#   'Dumbledore',
#   'Weasley',
#   'Harry',
#   'Harry',
#   'Sir',
#   'Professor Dumbledore',
#   'Dumbledore',
#   'Harry',
#   'Dumbledore',
#   'Harry',
#   'Dumbledore',
#   'Scabbers'],
#  'THIRTEEN': ['Dumbledore',
#   'Harry',
#   'Harry',
#   'Dumbledore',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Filch',
#   'Harry',
#   'Harry',
#   'Wood',
#   'Wood',
#   'Harry',
#   'Wood',
#   'Harry',
#   'Wood',
#   'Snape',
#   'George Weasley',
#   'Snape',
#   'George',
#   'Wood',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Snape',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Neville',
#   'Hermione',
#   'Neville',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Malfoy',
#   'Neville',
#   'Professor McGonagall',
#   'Hermione',
#   'Neville',
#   'Neville',
#   'Neville',
#   'Ron',
#   'Malfoy',
#   'Neville',
#   'Harry',
#   'Hermione',
#   'Neville',
#   'Malfoy',
#   'Harry',
#   'Malfoy',
#   'Neville',
#   'Harry',
#   'Neville',
#   'Harry',
#   'Dumbledore',
#   'Ron',
#   'Hermione',
#   'Dumbledore',
#   'Grindelwald',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Dumbledore',
#   'Harry',
#   'Snape',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Snape',
#   'Ron',
#   'Hermione',
#   'Snape',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Snape',
#   'Snape',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Wood',
#   'Ron',
#   'Hermione',
#   'Neville',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Malfoy',
#   'Neville',
#   'Snape',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Ron',
#   'Wood',
#   'Harry',
#   'Potter',
#   'Snape',
#   'Fred Weasley',
#   'Dumbledore',
#   'Harry',
#   'Dumbledore',
#   'Fred',
#   'Harry',
#   'Snape',
#   'Dumbledore',
#   'Snape',
#   'Ron',
#   'Snape',
#   'Hermione',
#   'Ron',
#   'Malfoy',
#   'Weasley',
#   'Malfoy',
#   'Crabbe',
#   'Goyle',
#   'Potter',
#   'Weasley',
#   'Ron',
#   'Snape',
#   'George Weasley',
#   'Hermione',
#   'Harry',
#   'Malfoy',
#   'Snape',
#   'Potter',
#   'Longbottom',
#   'Neville',
#   'Malfoy',
#   'Malfoy',
#   'Malfoy',
#   'Crabbe',
#   'Goyle',
#   'Ron',
#   'Neville',
#   'Longbottom',
#   'Weasley',
#   'Ron',
#   'Harry',
#   'Malfoy',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Weasley',
#   'Potter',
#   'Malfoy',
#   'Ron',
#   'Malfoy',
#   'Ron',
#   'Neville',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Snape',
#   'Malfoy',
#   'Ron',
#   'Neville',
#   'Crabbe',
#   'Goyle',
#   'Snape',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Parvati Patil',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Dumbledore',
#   'Dumbledore',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Snape',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Snape',
#   'Snape',
#   'Quirrell',
#   'Harry',
#   'Harry',
#   'Severus',
#   'Snape',
#   'Harry',
#   'Quirrell',
#   'Snape',
#   'Hagrid',
#   'Severus',
#   'Quirrell',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Snape',
#   'Harry',
#   'Quirrell',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Malfoy',
#   'Neville',
#   'Crabbe',
#   'Goyle',
#   'Madam',
#   'Fred',
#   'George',
#   'Harry',
#   'Peeves',
#   'Snape',
#   'Quirrell',
#   'Fluffy',
#   'Quirrell',
#   'Fluffy',
#   'Quirrell',
#   'Snape',
#   'Quirrell',
#   'Snape',
#   'Hermione',
#   'Ron'],
#  'FOURTEEN': ['Quirrell',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Fluffy',
#   'Snape',
#   'Harry',
#   'Quirrell',
#   'Ron',
#   'Quirrell',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Hermione',
#   'Moaning',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Hagrid',
#   'Hagrid',
#   'Ron',
#   'Hagrid',
#   'Harry',
#   'Fluffy',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hermione',
#   'Ron',
#   'Hagrid',
#   'Great',
#   'Hagrid',
#   'Harry',
#   'Ron',
#   'Charlie',
#   'Harry',
#   'Ron',
#   'Hagrid',
#   'Hermione',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Fluffy',
#   'Hagrid',
#   'Fluffy',
#   'Hagrid',
#   'Hermione',
#   'Hagrid',
#   'Hermione',
#   'Dumbledore',
#   'Hagrid',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Fluffy',
#   'Professor Sprout',
#   'Professor Flitwick',
#   'Professor McGonagall',
#   'Professor Quirrell',
#   'Dumbledore',
#   'Professor Snape',
#   'Snape',
#   'Snape',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Snape',
#   'Quirrell',
#   'Fluffy',
#   'Fluffy',
#   'Hagrid',
#   'Harry',
#   'Dumbledore',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Ron',
#   'Hagrid',
#   'Hermione',
#   'Hagrid',
#   'Hermione',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Hedwig',
#   'Harry',
#   'Hagrid',
#   'Ron',
#   'Hermione',
#   'Hermione',
#   'Hagrid',
#   'Harry',
#   'Malfoy',
#   'Harry',
#   'Malfoy',
#   'Ron',
#   'Hermione',
#   'Hermione',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Hermione',
#   'Hagrid',
#   'Harry',
#   'Malfoy',
#   'Malfoy',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Norbert',
#   'Hagrid',
#   'Norbert',
#   'Norbert',
#   'Ron',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Norbert',
#   'Malfoy',
#   'Dumbledore',
#   'Hagrid',
#   'Harry',
#   'Ron',
#   'Charlie',
#   'Ron',
#   'Ron',
#   'Charlie',
#   'Charlie',
#   'Norbert',
#   'Charlie',
#   'Ron',
#   'Hagrid',
#   'Hagrid',
#   'Charlie',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Hagrid',
#   'Norbert',
#   'Hagrid',
#   'Hedwig',
#   'Harry',
#   'Charlie',
#   'Ron',
#   'Charlie',
#   'Harry',
#   'Norbert',
#   'Norbert',
#   'Malfoy',
#   'Ron',
#   'Madam',
#   'Pomfrey',
#   'Norbert',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Malfoy',
#   'Madam',
#   'Pomfrey',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Charlie',
#   'Malfoy',
#   'Norbert',
#   'Harry',
#   'Hermione',
#   'Madam',
#   'Pomfrey',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Charlie',
#   'Norbert',
#   'Malfoy',
#   'Fang',
#   'Hagrid',
#   'Norbert',
#   'Charlie',
#   'Norbert',
#   'Harry',
#   'Hermione',
#   'Hagrid',
#   'Norbert',
#   'Hagrid',
#   'Peeves',
#   'Hagrid',
#   'Norbert',
#   'Hagrid',
#   'Harry',
#   'Norbert',
#   'Hagrid',
#   'Harry',
#   'Hermione',
#   'Norbert',
#   'Harry',
#   'Nearly',
#   'Harry',
#   'Professor McGonagall',
#   'Malfoy',
#   'Harry Potter',
#   'Professor Snape',
#   'Malfoy',
#   'Hermione',
#   'Malfoy',
#   'Harry',
#   'Malfoy',
#   'Norbert',
#   'Charlie',
#   'Harry',
#   'Hermione',
#   'Norbert',
#   'Norbert',
#   'Harry',
#   'Hermione',
#   'Norbert',
#   'Norbert',
#   'Malfoy',
#   'Filch'],
#  'FIFTEEN': ['Filch',
#   'Professor McGonagall',
#   'Hermione',
#   'Harry',
#   'Professor McGonagall',
#   'Norbert',
#   'Harry',
#   'Professor McGonagall',
#   'Neville',
#   'Harry',
#   'Neville',
#   'Malfoy',
#   'Harry',
#   'Neville',
#   'Professor McGonagall',
#   'Norbert',
#   'Mr. Filch',
#   'Hermione',
#   'Professor McGonagall',
#   'Draco Malfoy',
#   'Longbottom',
#   'Harry',
#   'Neville',
#   'Neville',
#   'Neville',
#   'Harry',
#   'Professor McGonagall',
#   'Miss Granger',
#   'Mr. Potter',
#   'Mr. Longbottom',
#   'Harry',
#   'Professor McGonagall',
#   'Potter',
#   'Harry',
#   'Harry',
#   'Neville',
#   'Harry',
#   'Neville',
#   'Harry Potter',
#   'Harry Potter',
#   'Harry',
#   'Harry',
#   'Potter',
#   'Ron',
#   'Fred',
#   'George',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Wood',
#   'Wood',
#   'Harry',
#   'Hermione',
#   'Neville',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Quirrell',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Quirrell',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Snape',
#   'Ron',
#   'Quirrell',
#   'Fluffy',
#   'Hermione',
#   'Snape',
#   'Hagrid',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Dumbledore',
#   'Harry',
#   'Quirrell',
#   'Snape',
#   'Filch',
#   'Snape',
#   'Fluffy',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Hermione',
#   'Neville',
#   'Mr. Filch',
#   'Professor McGonagall',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Neville',
#   'Filch',
#   'Malfoy',
#   'Harry',
#   'Malfoy',
#   'Filch',
#   'Neville',
#   'Harry',
#   'Filch',
#   'Harry',
#   'Hagrid',
#   'Filch',
#   'Harry',
#   'Hagrid',
#   'Filch',
#   'Neville',
#   'Malfoy',
#   'Neville',
#   'Harry',
#   'Filch',
#   'Hagrid',
#   'Fang',
#   'Harry',
#   'Hermione',
#   'Hagrid',
#   'Filch',
#   'Hagrid',
#   'Filch',
#   'Filch',
#   'Malfoy',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Malfoy',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Malfoy',
#   'Fang',
#   'Hagrid',
#   'Fang',
#   'Malfoy',
#   'Fang',
#   'Hagrid',
#   'Harry',
#   'Draco',
#   'Neville',
#   'Harry',
#   'Hermione',
#   'Hagrid',
#   'Malfoy',
#   'Neville',
#   'Fang',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Hermione',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hermione',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hermione',
#   'Ronan',
#   'Hagrid',
#   'Hagrid',
#   'Ronan',
#   'Ronan',
#   'Hagrid',
#   'Harry Potter',
#   'Hermione Granger',
#   'Ronan',
#   'Hermione',
#   'Ronan',
#   'Hermione',
#   'Ronan',
#   'Hagrid',
#   'Ronan',
#   'Ronan',
#   'Hagrid',
#   'Ronan',
#   'Ronan',
#   'Hagrid',
#   'Hagrid',
#   'Ronan',
#   'Ronan',
#   'Hagrid',
#   'Ronan',
#   'Bane',
#   'Hagrid',
#   'Hagrid',
#   'Ronan',
#   'Bane',
#   'Ronan',
#   'Hagrid',
#   'Harry',
#   'Hermione',
#   'Ronan',
#   'Bane',
#   'Hagrid',
#   'Hermione',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Hermione',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Hermione',
#   'Malfoy',
#   'Neville',
#   'Harry',
#   'Hagrid',
#   'Malfoy',
#   'Neville',
#   'Fang',
#   'Hagrid',
#   'Malfoy',
#   'Neville',
#   'Neville',
#   'Neville',
#   'Hermione',
#   'Harry',
#   'Fang',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Malfoy',
#   'Fang',
#   'Harry',
#   'Harry',
#   'Malfoy',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Malfoy',
#   'Fang',
#   'Malfoy',
#   'Fang',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Ronan',
#   'Bane',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Potter',
#   'Hagrid',
#   'Firenze',
#   'Harry',
#   'Ronan',
#   'Bane',
#   'Firenze',
#   'Bane',
#   'Firenze',
#   'Potter',
#   'Bane',
#   'Firenze',
#   'Ronan',
#   'Firenze',
#   'Bane',
#   'Firenze',
#   'Harry',
#   'Firenze',
#   'Bane',
#   'Bane',
#   'Firenze',
#   'Harry',
#   'Ronan',
#   'Bane',
#   'Harry',
#   'Bane',
#   'Firenze',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Firenze',
#   'Firenze',
#   'Harry Potter',
#   'Harry',
#   'Firenze',
#   'Harry',
#   'Firenze',
#   'Firenze',
#   'Mr. Potter',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Hermione',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Firenze',
#   'Hagrid',
#   'Harry',
#   'Harry Potter',
#   'Firenze',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Snape',
#   'Voldemort',
#   'Voldemort',
#   'Snape',
#   'Ron',
#   'Voldemort',
#   'Harry',
#   'Firenze',
#   'Bane',
#   'Voldemort',
#   'Bane',
#   'Firenze',
#   'Voldemort',
#   'Ron',
#   'Snape',
#   'Harry',
#   'Voldemort',
#   'Hermione',
#   'Harry',
#   'Dumbledore',
#   'Dumbledore',
#   'Professor McGonagall',
#   'Harry'],
#  'SIXTEEN': ['Harry',
#   'Voldemort',
#   'Fluffy',
#   'Professor Flitwick',
#   'Professor McGonagall',
#   'Snape',
#   'Harry',
#   'Neville',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Voldemort',
#   'Snape',
#   'Professor Binns',
#   'Harry',
#   'Hermione',
#   'Hermione',
#   'Ron',
#   'Weasley',
#   'Lee Jordan',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Madam',
#   'Pomfrey',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Dumbledore',
#   'Snape',
#   'Fluffy',
#   'Neville',
#   'Hagrid',
#   'Dumbledore',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Dumbledore',
#   'Hagrid',
#   'Fluffy',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Hagrid',
#   'Hermione',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Ron',
#   'Harry',
#   'Hagrid',
#   'Ron',
#   'Harry',
#   'Hagrid',
#   'Norbert',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Fluffy',
#   'Fluffy',
#   'Harry',
#   'Fluffy',
#   'Hagrid',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Dumbledore',
#   'Harry',
#   'Hagrid',
#   'Fluffy',
#   'Snape',
#   'Voldemort',
#   'Hagrid',
#   'Dumbledore',
#   'Firenze',
#   'Bane',
#   'Dumbledore',
#   'Dumbledore',
#   'Harry',
#   'Professor McGonagall',
#   'Professor Dumbledore',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Professor Dumbledore',
#   'Professor McGonagall',
#   'Harry',
#   'Professor McGonagall',
#   'Professor Dumbledore',
#   'Harry',
#   'Professor Dumbledore',
#   'Potter',
#   'Potter',
#   'Harry',
#   'Professor McGonagall',
#   'Professor Dumbledore',
#   'Professor Dumbledore',
#   'Potter',
#   'Harry',
#   'Professor McGonagall',
#   'Snape',
#   'Dumbledore',
#   'Dumbledore',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Potter',
#   'Harry',
#   'Snape',
#   'Hermione',
#   'Ron',
#   'Professor Flitwick',
#   'Professor Flitwick',
#   'Hermione',
#   'Snape',
#   'Harry',
#   'Ron',
#   'Fluffy',
#   'Professor McGonagall',
#   'Weasley',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Snape',
#   'Fat',
#   'Lady',
#   'Hermione',
#   'Harry',
#   'Snape',
#   'Flitwick',
#   'Snape',
#   'Snape',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'McGonagall',
#   'Snape',
#   'Harry',
#   'Snape',
#   'Voldemort',
#   'Voldemort',
#   'Voldemort',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Hermione',
#   'Flitwick',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Lee Jordan',
#   'Harry',
#   'Hagrid',
#   'Fluffy',
#   'Filch',
#   'Neville',
#   'Trevor',
#   'Neville',
#   'Harry',
#   'Neville',
#   'Hermione',
#   'Neville',
#   'Harry',
#   'Snape',
#   'Fluffy',
#   'Neville',
#   'Harry',
#   'Neville',
#   'Neville',
#   'Ron',
#   'Neville',
#   'Ron',
#   'Neville',
#   'Neville',
#   'Trevor',
#   'Neville',
#   'Harry',
#   'Hermione',
#   'Hermione',
#   'Neville',
#   'Neville',
#   'Neville',
#   'Hermione',
#   'Neville',
#   'Harry',
#   'Hermione',
#   'Neville',
#   'Neville',
#   'Harry',
#   'Neville',
#   'Ron',
#   'Neville',
#   'Filch',
#   'Peeves',
#   'Mrs.',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Mrs.',
#   'Peeves',
#   'Filch',
#   'Harry',
#   'Peeves',
#   'Bloody',
#   'Baron',
#   'Peeves',
#   'Mr. Baron',
#   'Sir',
#   'Peeves',
#   'Harry',
#   'Peeves',
#   'Baron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Snape',
#   'Fluffy',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Snape',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Hedwig',
#   'Dumbledore',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Professor Sprout',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Snape',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Norbert',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Snape',
#   'Ron',
#   'Ron',
#   'Ron',
#   'Hermione',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Sprout',
#   'Flitwick',
#   'McGonagall',
#   'Quirrell',
#   'Snape',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Hermione',
#   'Hermione',
#   'Hermione',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Ron',
#   'Fluffy',
#   'Hedwig',
#   'Dumbledore',
#   'Snape',
#   'Harry',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Snape',
#   'Voldemort'],
#  'SEVENTEEN': ['Quirrell',
#   'Harry',
#   'Quirrell',
#   'Potter',
#   'Snape',
#   'Severus',
#   'Quirrell',
#   'Severus',
#   'Professor Quirrell',
#   'Harry',
#   'Snape',
#   'Miss Granger',
#   'Snape',
#   'Snape',
#   'Snape',
#   'Quirrell',
#   'Dumbledore',
#   'Snape',
#   'Quirrell',
#   'Harry',
#   'Potter',
#   'Snape',
#   'Snape',
#   'Potter',
#   'Harry',
#   'Quirrell',
#   'Quirrell',
#   'Dumbledore',
#   'Harry',
#   'Quirrell',
#   'Snape',
#   'Quirrell',
#   'Lord Voldemort',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Snape',
#   'Quirrell',
#   'Snape',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Lord Voldemort',
#   'Quirrell',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Quirrell',
#   'Quirrell',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Quirrell',
#   'Harry',
#   'Potter',
#   'Harry',
#   'Harry',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Harry',
#   'Dumbledore',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Potter',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Harry',
#   'Harry Potter',
#   'Harry',
#   'Quirrell',
#   'Harry',
#   'Harry',
#   'Quirrell',
#   'Voldemort',
#   'Harry',
#   'Voldemort',
#   'Harry',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Quirrell',
#   'Voldemort',
#   'Quirrell',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Quirrell',
#   'Quirrell',
#   'Harry',
#   'Harry',
#   'Voldemort',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Quirrell',
#   'Harry',
#   'Quirrell',
#   'Quirrell',
#   'Harry',
#   'Harry',
#   'Quirrell',
#   'Voldemort',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Quirrell',
#   'Albus Dumbledore',
#   'Harry',
#   'Dumbledore',
#   'Harry',
#   'Sir',
#   'Quirrell',
#   'Sir',
#   'Dumbledore',
#   'Quirrell',
#   'Sir',
#   'Harry',
#   'Madam',
#   'Pomfrey',
#   'Harry',
#   'Dumbledore',
#   'Professor Quirrell',
#   'Fred',
#   'George Weasley',
#   'Madam',
#   'Pomfrey',
#   'Weasley',
#   'Miss Granger',
#   'Professor Quirrell',
#   'Hermione',
#   'Quirrell',
#   'Harry',
#   'Dumbledore',
#   'Dumbledore',
#   'Harry',
#   'Harry',
#   'Dumbledore',
#   'Sir',
#   'Harry',
#   'Voldemort',
#   'Harry',
#   'Voldemort',
#   'Harry',
#   'Quirrell',
#   'Harry',
#   'Harry',
#   'Sir',
#   'Dumbledore',
#   'Voldemort',
#   'Dumbledore',
#   'Harry',
#   'Harry',
#   'Quirrell',
#   'Voldemort',
#   'Quirrell',
#   'Voldemort',
#   'Dumbledore',
#   'Harry',
#   'Harry',
#   'Dumbledore',
#   'Quirrell',
#   'Snape',
#   'Professor Snape',
#   'Harry',
#   'Quirrell',
#   'Mr. Malfoy',
#   'Snape',
#   'Dumbledore',
#   'Professor Snape',
#   'Harry',
#   'Madam',
#   'Pomfrey',
#   'Harry',
#   'Professor Dumbledore',
#   'Madam',
#   'Pomfrey',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Hermione',
#   'Harry',
#   'Harry',
#   'Dumbledore',
#   'Ron',
#   'Harry',
#   'Quirrell',
#   'Voldemort',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Quirrell',
#   'Hermione',
#   'Ron',
#   'Dumbledore',
#   'Ron',
#   'Harry',
#   'Hermione',
#   'Ron',
#   'Dumbledore',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Harry',
#   'Dumbledore',
#   'Voldemort',
#   'Dumbledore',
#   'Ron',
#   'Ravenclaw',
#   'Madam',
#   'Pomfrey',
#   'Harry',
#   'Madam',
#   'Pomfrey',
#   'Professor Dumbledore',
#   'Professor Dumbledore',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Fluffy',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Voldemort',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Hagrid',
#   'Hagrid',
#   'Harry',
#   'Hagrid',
#   'Dumbledore',
#   'Harry',
#   'Harry',
#   'Hagrid',
#   'Harry',
#   'Madam',
#   'Pomfrey',
#   'Great',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Dumbledore',
#   'Dumbledore',
#   'Ravenclaw',
#   'Harry',
#   'Draco Malfoy',
#   'Dumbledore',
#   'Dumbledore',
#   'Weasley',
#   'Ron',
#   'Percy',
#   'McGonagall',
#   'Miss Hermione Granger',
#   'Hermione',
#   'Harry',
#   'Mr. Harry Potter',
#   'Dumbledore',
#   'Dumbledore',
#   'Harry',
#   'Dumbledore',
#   'Dumbledore',
#   'Mr. Neville Longbottom',
#   'Great',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Neville',
#   'Harry',
#   'Ron',
#   'Malfoy',
#   'Dumbledore',
#   'Ravenclaw',
#   'Snape',
#   'Professor McGonagall',
#   'Harry',
#   'Harry',
#   'Snape',
#   'Harry',
#   'Harry',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Neville',
#   'Goyle',
#   'Ron',
#   'Neville',
#   'Fred Weasley',
#   'Hagrid',
#   'Ron',
#   'Harry',
#   'Harry',
#   'Potter',
#   'Ron',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Ginny Weasley',
#   'Ron',
#   'Ron',
#   'Harry Potter',
#   'Ginny',
#   'Mrs. Weasley',
#   'Harry',
#   'Mrs. Weasley',
#   'Uncle Vernon',
#   'Harry',
#   'Aunt Petunia',
#   'Dudley',
#   'Harry',
#   'Harry',
#   'Mrs. Weasley',
#   'Uncle Vernon',
#   'Harry',
#   'Ron',
#   'Hermione',
#   'Hermione',
#   'Uncle Vernon',
#   'Harry',
#   'Dudley']}
